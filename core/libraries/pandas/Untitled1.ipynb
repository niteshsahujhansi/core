# %%
from pandas import Series, read_excel, Timestamp

# %%
df_ = read_excel("sales_register_4983.xlsx")

# %%
df_
# Out:
#        Customer Name  Document number Document Date  \
# 0    NewPTEntity00004      1000000001    2022-03-31
# 1    NewPTEntity00004      4100362123    2021-12-31
# 2    NewPTEntity00004      4100378811    2022-03-31
# 3    NewPTEntity00004      4100355215    2021-09-30
# 4    NewPTEntity00004      4100368370    2021-12-31
# ..                ...             ...           ...
# 144  NewPTEntity00004      4100354452    2021-09-30
# 145  NewPTEntity00004      4100372956    2022-03-31
# 146  NewPTEntity00004      4100356819    2021-12-31
# 147  NewPTEntity00004      4100373339    2022-03-31
# 148  NewPTEntity00004      4100341824    2021-06-30
#
#      Amount in Foreign Currency  Currency  Conversion rate  Amount in INR  \
# 0                         329.00      EUR            83.49   2.746821e+04
# 1                       14043.00      EUR            83.49   1.172450e+06
# 2                          67.00      EUR            83.49   5.593830e+03
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 search_value = 'NewPTEntity00004'
# ----> 2 result = df['NewPTEntity00004']
#
# NameError: name 'df' is not defined

# %%
# Out:
# array(['NewPTEntity00004', 1000000001, Timestamp('2022-03-31 00:00:00'),
#        329.0, 'EUR', 83.49, 27468.21, 0.0, 0.0, 'Offshore supply'],
#       dtype=object)
